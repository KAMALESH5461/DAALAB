# %% [markdown]
# <a href="https://colab.research.google.com/github/KAMALESH5461/DAALAB/blob/main/1c.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random


def interpolation_search_float(arr, target):
    low = 0
    high = len(arr) - 1
    comparisons = 0

    while (
        low <= high
        and target >= arr[low]
        and target <= arr[high]
    ):

        comparisons += 1

        # Avoid division by zero
        if arr[low] == arr[high]:
            if abs(arr[low] - target) < 1e-9:
                return low, comparisons
            return -1, comparisons

        # Estimate position
        pos = low + int(
            ((target - arr[low]) * (high - low))
            / (arr[high] - arr[low])
        )

        # Safety check
        if pos < low or pos > high:
            break

        # Float comparison tolerance
        if abs(arr[pos] - target) < 1e-6:
            return pos, comparisons

        elif arr[pos] < target:
            low = pos + 1

        else:
            high = pos - 1

    return -1, comparisons


# Dataset sizes
sizes = [10000, 50000, 100000]

print("Interpolation Search Analysis\n")

for size in sizes:

    # Generate uniformly distributed floats
    data = sorted(
        random.uniform(0.0, 1000.0)
        for _ in range(size)
    )

    # Select existing value for successful search
    target = data[random.randint(0, size - 1)]

    index, comparisons = interpolation_search_float(
        data,
        target
    )

    print(f"Dataset Size : {size}")
    print(f"Target Value : {target:.4f}")
    print(f"Found Index  : {index}")
    print(f"Comparisons  : {comparisons}")
    print("-" * 35)
# Out:
# Interpolation Search Analysis
#
# Dataset Size : 10000
# Target Value : 805.9341
# Found Index  : 8082
# Comparisons  : 3
# -----------------------------------
# Dataset Size : 50000
# Target Value : 256.3191
# Found Index  : 12705
# Comparisons  : 4
# -----------------------------------
# Dataset Size : 100000
# Target Value : 65.5202
# Found Index  : 6705
# Comparisons  : 4
# -----------------------------------
